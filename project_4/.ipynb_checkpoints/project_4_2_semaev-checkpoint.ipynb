# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# ## Комментарий ревьювера
#
# Михаил, привет!
#
# 🤚Меня зовут, Олег Юрьев, я буду проверять твой проект. Если не против, я буду обращаться к тебе на _ТЫ_ . Если это неприемлемо, обязательно напиши мне в комментариях - мы перейдем на _ВЫ_ .
#
# 🤝Спасибо, что сдал проект вовремя. Тобой проделана большая работа, молодец!
#
# ✏️В этой тетрадке ты найдешь мои комментарии.
#
# Комментарии будут выделены:
#
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
#     Безупречная работа</div>
# <br>
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
#     Ничего дорабатывать не надо, данные пункты работают нормально, но есть способы улучшить. Несколько таких комментариев допустимы, но более - придется некоторые доработать. Большое кол-во мелких замечаний и помарок сказываются на общем впечатлении от работы.</div>
# <br>
# <div style="border:solid red 2px; padding: 20px"> <b>Что необходимо доработать</b><br>
#     Такие пункты необходимо исправить в первую очередь, чтобы я смог принять проект.</div>
#
# Не удаляй комментарии, так будем следить за динамикой 📈
#
# Давай будем в диалоге - основные цели в диалоге:
# - обмен опытом (да я тоже учусь у студентов👨‍🎓)
# - выполнить проект еще лучше
# - помочь тебе стать аналитиком
#
# Поэтому чтобы мне проще было проверять повторно, а тебе контролировать процесс ревью, оставляй свои комментарии и выделяй их.
#
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Поехали! :)
#
# <hr style="border: 2px solid green;" />

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Привет, Олег!
#
# Буду отвечать в таких блоках в дальнейшем.
#
#
# </div>
#
# ---

# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Комментарий-ревьювера" data-toc-modified-id="Комментарий-ревьювера-0.1">Комментарий ревьювера</a></span><ul class="toc-item"><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-0.1.1">Комментарий студента</a></span></li></ul></li></ul></li><li><span><a href="#Определение-перспективного-тарифа-для-телеком-компании" data-toc-modified-id="Определение-перспективного-тарифа-для-телеком-компании-1">Определение перспективного тарифа для телеком компании</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1">Описание проекта</a></span></li><li><span><a href="#Шаг-1.-Изучение-данных" data-toc-modified-id="Шаг-1.-Изучение-данных-1.2">Шаг 1. Изучение данных</a></span><ul class="toc-item"><li><span><a href="#Таблица-users" data-toc-modified-id="Таблица-users-1.2.1">Таблица users</a></span></li><li><span><a href="#Таблица-calls" data-toc-modified-id="Таблица-calls-1.2.2">Таблица calls</a></span></li><li><span><a href="#Таблица-internet" data-toc-modified-id="Таблица-internet-1.2.3">Таблица internet</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.2.4">Комментарий студента</a></span></li><li><span><a href="#Таблица-messages" data-toc-modified-id="Таблица-messages-1.2.5">Таблица messages</a></span></li><li><span><a href="#Таблица-tariffs" data-toc-modified-id="Таблица-tariffs-1.2.6">Таблица tariffs</a></span></li></ul></li><li><span><a href="#Шаг-2.-Подготовка-данных" data-toc-modified-id="Шаг-2.-Подготовка-данных-1.3">Шаг 2. Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Таблица-users" data-toc-modified-id="Таблица-users-1.3.1">Таблица users</a></span><ul class="toc-item"><li><span><a href="#Проверка-уникальности-данных" data-toc-modified-id="Проверка-уникальности-данных-1.3.1.1">Проверка уникальности данных</a></span></li><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-1.3.1.2">Замена типа данных</a></span></li></ul></li><li><span><a href="#Таблица-calls" data-toc-modified-id="Таблица-calls-1.3.2">Таблица calls</a></span><ul class="toc-item"><li><span><a href="#Проверка-данных-в-столбце-'duration'" data-toc-modified-id="Проверка-данных-в-столбце-'duration'-1.3.2.1">Проверка данных в столбце 'duration'</a></span></li></ul></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.3">Комментарий студента</a></span><ul class="toc-item"><li><span><a href="#Замена-типа-данных-и-округление-времени-звонков" data-toc-modified-id="Замена-типа-данных-и-округление-времени-звонков-1.3.3.1">Замена типа данных и округление времени звонков</a></span></li><li><span><a href="#Подсчет-количества-звонков-по-месяцам" data-toc-modified-id="Подсчет-количества-звонков-по-месяцам-1.3.3.2">Подсчет количества звонков по месяцам</a></span></li><li><span><a href="#Подсчет-количества-минут-по-месяцам" data-toc-modified-id="Подсчет-количества-минут-по-месяцам-1.3.3.3">Подсчет количества минут по месяцам</a></span></li><li><span><a href="#Барплот-для-количества-звонков-и-минут" data-toc-modified-id="Барплот-для-количества-звонков-и-минут-1.3.3.4">Барплот для количества звонков и минут</a></span></li></ul></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.4">Комментарий студента</a></span></li><li><span><a href="#Таблица-internet" data-toc-modified-id="Таблица-internet-1.3.5">Таблица internet</a></span><ul class="toc-item"><li><span><a href="#Проверка-данных-в-столбце-'mb_used'" data-toc-modified-id="Проверка-данных-в-столбце-'mb_used'-1.3.5.1">Проверка данных в столбце 'mb_used'</a></span></li><li><span><a href="#Замена-типа-данных,-округление-потраченных-мб" data-toc-modified-id="Замена-типа-данных,-округление-потраченных-мб-1.3.5.2">Замена типа данных, округление потраченных мб</a></span></li><li><span><a href="#Подсчет-объема-интернет-трафика-по-месяцам" data-toc-modified-id="Подсчет-объема-интернет-трафика-по-месяцам-1.3.5.3">Подсчет объема интернет-трафика по месяцам</a></span></li></ul></li><li><span><a href="#Таблица-messages" data-toc-modified-id="Таблица-messages-1.3.6">Таблица messages</a></span><ul class="toc-item"><li><span><a href="#Замена-типа-данных" data-toc-modified-id="Замена-типа-данных-1.3.6.1">Замена типа данных</a></span></li><li><span><a href="#Подсчет-количества-отправленных-сообщений-по-месяцам" data-toc-modified-id="Подсчет-количества-отправленных-сообщений-по-месяцам-1.3.6.2">Подсчет количества отправленных сообщений по месяцам</a></span></li></ul></li><li><span><a href="#Таблица-tariffs" data-toc-modified-id="Таблица-tariffs-1.3.7">Таблица tariffs</a></span></li><li><span><a href="#Подсчет-помесячной-выручки-с-каждого-пользователя" data-toc-modified-id="Подсчет-помесячной-выручки-с-каждого-пользователя-1.3.8">Подсчет помесячной выручки с каждого пользователя</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.9">Комментарий студента</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.3.10">Комментарий студента</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.3.11">Выводы</a></span></li></ul></li><li><span><a href="#Шаг-3.-Анализ-данных" data-toc-modified-id="Шаг-3.-Анализ-данных-1.4">Шаг 3. Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Описание-поведения-клиентов-оператора,-исходя-из-выборки" data-toc-modified-id="Описание-поведения-клиентов-оператора,-исходя-из-выборки-1.4.1">Описание поведения клиентов оператора, исходя из выборки</a></span><ul class="toc-item"><li><span><a href="#Процент-клиентов-с-расходами-сверх-абонентской-платы" data-toc-modified-id="Процент-клиентов-с-расходами-сверх-абонентской-платы-1.4.1.1">Процент клиентов с расходами сверх абонентской платы</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-1.4.1.2">Выводы</a></span></li></ul></li><li><span><a href="#Детальное-рассмотрение-тарифов" data-toc-modified-id="Детальное-рассмотрение-тарифов-1.4.2">Детальное рассмотрение тарифов</a></span><ul class="toc-item"><li><span><a href="#Тариф-Smart" data-toc-modified-id="Тариф-Smart-1.4.2.1">Тариф Smart</a></span></li></ul></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.3">Комментарий студента</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.4">Комментарий студента</a></span><ul class="toc-item"><li><span><a href="#Тариф-Ultra" data-toc-modified-id="Тариф-Ultra-1.4.4.1">Тариф Ultra</a></span></li></ul></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-1.4.5">Комментарий студента</a></span></li></ul></li><li><span><a href="#Шаг-4.-Проверка-гипотез" data-toc-modified-id="Шаг-4.-Проверка-гипотез-1.5">Шаг 4. Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1.-Cредняя-выручка-пользователей-тарифов-«Ultra»-и-«Smart»-различается" data-toc-modified-id="Гипотеза-1.-Cредняя-выручка-пользователей-тарифов-«Ultra»-и-«Smart»-различается-1.5.1">Гипотеза 1. Cредняя выручка пользователей тарифов «Ultra» и «Smart» различается</a></span></li><li><span><a href="#Гипотеза-2.-Средняя-выручка-пользователей-из-Москвы-отличается-от-выручки-пользователей-из-других-регионов" data-toc-modified-id="Гипотеза-2.-Средняя-выручка-пользователей-из-Москвы-отличается-от-выручки-пользователей-из-других-регионов-1.5.2">Гипотеза 2. Средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов</a></span></li></ul></li><li><span><a href="#Шаг-5.-Общий-вывод" data-toc-modified-id="Шаг-5.-Общий-вывод-1.6">Шаг 5. Общий вывод</a></span></li><li><span><a href="#Общий-комментарий" data-toc-modified-id="Общий-комментарий-1.7">Общий комментарий</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Определение перспективного тарифа для телеком компании

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Вы аналитик компании «Мегалайн» — федерального оператора сотовой связи. Клиентам предлагают два тарифных плана: «Смарт» и «Ультра». Чтобы скорректировать рекламный бюджет, коммерческий департамент хочет понять, какой тариф приносит больше денег.
# Вам предстоит сделать предварительный анализ тарифов на небольшой выборке клиентов. В вашем распоряжении данные 500 пользователей «Мегалайна»: кто они, откуда, каким тарифом пользуются, сколько звонков и сообщений каждый отправил за 2018 год. Нужно проанализировать поведение клиентов и сделать вывод — какой тариф лучше.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Молодец, что формулируешь вводную информацию - она помогает понять о чем и что будет происходить. Будет круче, если более четко формализовать цель или разбить ее на части</div> <br>

# %% [markdown]
# ## Шаг 1. Изучение данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats as st
from functools import reduce

pd.options.display.max_columns = None
pd.options.display.float_format = "{:.2f}".format

# %%
try:
    users = pd.read_csv('/Users/mikhail/Desktop/praktikum/project_4/users.csv')
    calls = pd.read_csv('/Users/mikhail/Desktop/praktikum/project_4/calls.csv')
    internet = pd.read_csv('/Users/mikhail/Desktop/praktikum/project_4/internet.csv', index_col=0)
    messages = pd.read_csv('/Users/mikhail/Desktop/praktikum/project_4/messages.csv')
    tariffs = pd.read_csv('/Users/mikhail/Desktop/praktikum/project_4/tariffs.csv')
except:
    users = pd.read_csv('/datasets/users.csv')
    calls = pd.read_csv('/datasets/calls.csv')
    internet = pd.read_csv('/datasets/internet.csv', index_col=0)
    messages = pd.read_csv('/datasets/messages.csv')
    tariffs = pd.read_csv('/datasets/tariffs.csv')

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# <img src=https://cs.pikabu.ru/images/big_size_comm/2013-11_2/13840927177437.jpg></div> <br>

# %% [markdown]
# ### Таблица users

# %%
display(users.head())
display(users.info(), users.describe())
# Out:
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# 4     1004   68        NaN  Новокузнецк    Татьяна   Авдеенко  2018-05-14
#
#   tariff
# 0  ultra
# 1  smart
# 2  smart
# 3  ultra
# 4  ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
# None
#        user_id    age
# count   500.00 500.00
# mean   1249.50  46.59
# std     144.48  16.67
# min    1000.00  18.00
# 25%    1124.75  32.00
# 50%    1249.50  46.00
# 75%    1374.25  62.00
# max    1499.00  75.00

# %% [markdown]
# В данной таблице у нас 500 строк с данными о 500 случайных пользователях "Мегалайн".
#
# Имеем 8 столбцов, из которых только один ('churn_date') имеет пропуски, но их очень много.
# Данный столбец содержит дату прекращения тарифа. Nan в данном случае означает, что пользователь все еще подключен.
# Поэтому заполнять их не будем.
#
# В столбце 'reg_date' необходимо перевести тип данных в datetime.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Здравая мысль, что пропуск в <code>churn_date</code> - клиент действующий и не трогать пропуски</div> <br>

# %% [markdown]
# ### Таблица calls

# %%
display(calls.head())
display(calls.info(), calls.describe())
# Out:
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
# None
#        duration   user_id
# count 202607.00 202607.00
# mean       6.76   1253.94
# std        5.84    144.72
# min        0.00   1000.00
# 25%        1.30   1126.00
# 50%        6.00   1260.00
# 75%       10.70   1379.00
# max       38.00   1499.00

# %% [markdown]
# Имеем датафрейм, который содержит информацию о звонках пользователей на 202607 строк и 4 столбца. Пропусков нет.
#
# Столбец 'call_date' необходимо перевести в формат datetime.
# Согласно условиям оператора - длительность звонков округляется в большу сторону, даже если длительность была всего 1 секунду. Соответственно нам необходимо в столбце 'duration' округлить количество минут и перевести тип данных в int.

# %% [markdown]
# ### Таблица internet

# %%
display(internet.head())
display(internet.info(), internet.describe())
# Out:
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149396 entries, 0 to 149395
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            149396 non-null  object
#  1   mb_used       149396 non-null  float64
#  2   session_date  149396 non-null  object
#  3   user_id       149396 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 5.7+ MB
# None
#         mb_used   user_id
# count 149396.00 149396.00
# mean     370.19   1252.10
# std      278.30    144.05
# min        0.00   1000.00
# 25%      138.19   1130.00
# 50%      348.01   1251.00
# 75%      559.55   1380.00
# max     1724.83   1499.00

# %% [markdown]
# Данная таблица содержит информацию о интернет сессиях избранных 500 пользователей и несет в себе 149396 строк и 5 столбцов. Попусков нет.
#
# Столбец 'Unnamed: 0' явно дублирует индексы строк и от него необходимо избавиться, применив index_col=0 при чтении файла.
#
# Данные столбца 'mb_used' так же необходимо окргулить в большую сторону и перевести данные в int.
#
# Столбец 'session_date' содержит данные о дате совершения звонка, поэтому переведем его в тип datetime.

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
# <code>Unnamed: 0</code> - означает, что данные были сохраненя с указанием индекса, чтобы им снова воспользоваться, нужно использовать опцию <code>index_col=0</code></div> <br>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Благодарю! Новый проект - новые знания! Применил метод.
#
#
# </div>
#
# ---

# %% [markdown]
# ### Таблица messages

# %%
display(messages.head())
display(messages.info(), messages.describe())
# Out:
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB
# None
#         user_id
# count 123036.00
# mean    1256.99
# std      143.52
# min     1000.00
# 25%     1134.00
# 50%     1271.00
# 75%     1381.00
# max     1499.00

# %% [markdown]
# Таблица messages содержит информацию об отправленных сообщениях - 123036 строк и 3 столбца. И не содержит пропусков.
#
# Столбец 'message_date' необходимо привести к типу datetime.

# %% [markdown]
# ### Таблица tariffs

# %%
display(tariffs.head())
display(tariffs.info(), tariffs.describe())
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes
# None
#        messages_included  mb_per_month_included  minutes_included  \
# count               2.00                   2.00              2.00
# mean              525.00               23040.00           1750.00
# std               671.75               10861.16           1767.77
# min                50.00               15360.00            500.00
# 25%               287.50               19200.00           1125.00
# 50%               525.00               23040.00           1750.00
# 75%               762.50               26880.00           2375.00
# max              1000.00               30720.00           3000.00
#
#        rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# count             2.00        2.00             2.00            2.00
# mean           1250.00      175.00             2.00            2.00
# std             989.95       35.36             1.41            1.41
# min             550.00      150.00             1.00            1.00
# 25%             900.00      162.50             1.50            1.50
# 50%            1250.00      175.00             2.00            2.00
# 75%            1600.00      187.50             2.50            2.50
# max            1950.00      200.00             3.00            3.00

# %% [markdown]
# Таблица содержит информацию о тарифах - всего 2 строки и 8 столбцов. Нет пропусков и все типы данных соответствуют норме.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Обзор данных выполнен отлично!</div> <br>

# %% [markdown]
# ## Шаг 2. Подготовка данных

# %% [markdown]
# ### Таблица users

# %% [markdown]
# #### Проверка уникальности данных

# %%
# убедимся, что в таблице нет дубликатов

users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Отлично, работаем дальше (c)

# %% [markdown]
# #### Замена типа данных

# %%
# заменим тип данных в столбцах 'reg_date' и 'churn_date' на datetime.

users['reg_date'] = pd.to_datetime(users['reg_date'], format = '%Y-%m-%d')
users['churn_date'] = pd.to_datetime(users['churn_date'], format = '%Y-%m-%d')

users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     datetime64[ns]
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    datetime64[ns]
#  7   tariff      500 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 31.4+ KB

# %%
# проверим данные в столбце 'churn_date'
# len_churn = len(users[pd.notnull(users['churn_date'])])
# print(f' Число не нулевых строк в столбце churn_date по-прежнему {len_churn}')

# %% [markdown]
# ### Таблица calls

# %% [markdown]
# #### Проверка данных в столбце 'duration'

# %%
# в столбце 'duration' стоит оценить количество звонков с продолжительностью 0 минут

len(calls[calls['duration'] == 0])
# Out:
# 39613

# %% [markdown]
# Довольно большое количество - порядка 25%. Возможно, это действительно безответные звонки. В наше время, когда многие предпочитают звонкам чаты, мессенджеры и голосовые сообщения внутри интернет-коммуникаций - не вижу удивительного в таком количестве нулевых значений. Но для проверки данных все же построим гистограмму по количеству пропущенных звонков для кажого пользователя.

# %%
# на всякий случай посмотрим какие абоненты (по user_id) 
# и в каком количестве имеют нулевые звонки

zero_calls = calls[calls['duration'] == 0].groupby('user_id')['duration'].count()
zero_calls = zero_calls.reset_index()

# %%
# построим диаграмму 

g=sns.relplot(data=zero_calls, x='user_id', y='duration', color='red')
try:
    sns.rugplot(data=zero_calls, x='user_id', y='duration', color='red')
except:
    pass
g.fig.set_size_inches(12,8)
plt.title('Распределение безответных звонков по пользователям ', fontsize=14)
plt.xlabel('Пользователи', fontsize=12)
plt.ylabel('Количество безответных звонков', fontsize=12)
plt.show()

# %% [markdown]
# <div style="border:solid red 2px; padding: 20px"> <b>Комментарий</b><br>
# В ячейке выше возникала ошибка - отсутствует параметр a для rigplot - так происходит, вероятно, потому что ты выполнял работу локально и у тебя отличная версия <code>seaborn</code>. В окружении практикума версия = <b>0.9.0</b>. Я вставил  конструкцию <code>try\except</code>, чтобы код отрабатывал без ошибок (но так может быть не всегда, неисполнение программы без ошибок - это причина возврата на доработку). Если тебе необходимо, чтобы график всегда был таким как ты задумал, нужно или писать конструкции <code>if\else</code> с проверкой версии библиотеки или установить у себя окружение как в Практикуме (как это сделать обратись к куратору)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Благодарю! И прошу прощения. Обязательно учту в дальнейшем.
#
# Мне кажется это крайне "не очень", что и вас и нас заставляют работать в среде, которая слегка устарела.
#
# </div>
#
# ---

# %% [markdown]
# В целом - данные довольно равномерно распределены по пользователям и можно оставить их без изменений.
#
# Но мы поступим иначе - заменим 0 на Nan и удалим строки с этими данными: такие данные будут скорее выбросами.

# %%
calls['duration'] = calls['duration'].replace(0, np.NaN)
calls = calls.dropna()

# %% [markdown]
# #### Замена типа данных и округление времени звонков

# %%
# заменим тип данных в столбцах 'call_date' таблицы users на datetime.

calls['call_date'] = pd.to_datetime(calls['call_date'], format = '%Y-%m-%d')

# %%
# округлим данные о времени звонков в большую сторону 
# и сразу же перведем данные в целочисленный тип

calls['duration'] = calls['duration'].apply(np.ceil).astype(int)

# %%
calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 162994 entries, 2 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         162994 non-null  object
#  1   call_date  162994 non-null  datetime64[ns]
#  2   duration   162994 non-null  int64
#  3   user_id    162994 non-null  int64
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 6.2+ MB

# %% [markdown]
# #### Подсчет количества звонков по месяцам

# %%
# добавим новый столбец с названием месяца 

calls['month'] = calls['call_date'].dt.month_name()

# %%
# посчитаем количество звонков по месяцам 

calls_per_month = calls['month'].value_counts()
calls_per_month
# Out:
# December     27385
# November     23664
# October      21757
# September    19446
# August       17257
# July         14780
# June         11833
# May          10116
# April         7504
# March         5383
# February      2705
# January       1164
# Name: month, dtype: int64

# %% [markdown]
# Топ-3 месяца по количеству звонков - декабрь, ноябрь, октябрь. Предновогодние месяцы самые активные.
#
# В то же время - после НГ происходит явный спад в желании общаться голосом.

# %% [markdown]
# #### Подсчет количества минут по месяцам

# %%
minutes_per_month = calls.groupby('month')['duration'].sum().sort_values(ascending=False)
minutes_per_month
# Out:
# month
# December     243675
# November     210089
# October      193928
# September    173475
# August       153698
# July         131746
# June         105180
# May           88810
# April         66310
# March         48151
# February      24455
# January       10784
# Name: duration, dtype: int64

# %% [markdown]
# Все в точности похоже на ситуйцию с количеством звонков - больше и дольше всего разговаривают по телефону в предновогодние месяцы. После НГ - спад и затем снова увеличается количество минут.

# %% [markdown]
# #### Барплот для количества звонков и минут

# %% [markdown]
# Для большей наглядности визуализируем данные вычислений

# %%
# создаем общую таблицу с данными по количеству звонков и минут 

calls_with_minutes = pd.concat([minutes_per_month, calls_per_month], axis = 1)
# создаем сводный график по месяцам для количества звонков и минут

ax = calls_with_minutes.plot.bar(figsize=(14,8), color=['r','y'], width=0.9, rot=30)
ax.legend(['Количество минут', 'Количество звонков']);

for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., \
                                      p.get_height()), ha = 'center', va = 'center', \
                xytext = (0, 10), textcoords = 'offset points')

plt.title('Количество минут и звонков по месяцам', fontsize=14)
plt.xlabel('Месяцы', fontsize=12)
plt.ylabel('Количество',fontsize=12)
plt.show()

# %% [markdown]
# Полная корреляция - чем больше, звонков - тем больше минут.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Достаточно логично =)</div> <br>
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
# Рекомендую, если есть время на графиках - никак не искажать и не переворачить временную ось, а располагать ее по оси Х</div> <br>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
# Визуализацию поправил
#
#
# </div>
#
# ---

# %% [markdown]
# ### Таблица internet

# %% [markdown]
# #### Проверка данных в столбце 'mb_used'

# %% [markdown]
# Как и в случае с продолжительностью звонков стоит проверить интернет-сессии с 0 мб.

# %%
len(internet[internet['mb_used']==0])
# Out:
# 19598

# %% [markdown]
# Снова получаем довольно большой процент (порядка 13%) показателей равных 0.
#
# Так же сгруппируем данные для дальнейшей визуализации.

# %%
zero_mb = internet[internet['mb_used']==0].groupby('user_id')['mb_used'].count()
zero_mb = zero_mb.reset_index()

# %%
# построим диаграмму 

g=sns.relplot(data=zero_mb, x='user_id', y='mb_used', color='green')
try:
    sns.rugplot(data=zero_mb, x='user_id', y='mb_used', color='green')
except:
    pass
g.fig.set_size_inches(12,8)
plt.title('Распределение "нулевых" интернет-сессий по пользователям ', fontsize=14)
plt.xlabel('Пользователи', fontsize=12)
plt.ylabel('Количество сессий равных 0 мб', fontsize=12)
plt.show()

# %% [markdown]
# Довольно равномерно и без каких либо отклонений.
#
# Избавимся от нулевых значений.

# %%
internet['mb_used'] = internet['mb_used'].replace(0, np.NaN)
internet = internet.dropna()

# %% [markdown]
# #### Замена типа данных, округление потраченных мб

# %%
# переведем тип данных столбца 'session_date' в  datetime

internet['session_date'] = pd.to_datetime(internet['session_date'], format = '%Y-%m-%d')

# %%
# округлим данные о потраченных мб в большую сторону 
# и сразу же перведем данные в целочисленный тип

internet['mb_used'] = internet['mb_used'].apply(np.ceil).astype(int)

# %% [markdown]
# #### Подсчет объема интернет-трафика по месяцам

# %%
# добавим новый столбец с названием месяца 

internet['month'] = internet['session_date'].dt.month_name()

# %%
# посчитаем количество потраченных мб по месяцам 

mb_per_month = internet.groupby('month')['mb_used'].sum().sort_values(ascending=False)
mb_per_month
# Out:
# month
# December     9144202
# November     7999852
# October      7400754
# September    6454931
# August       6005126
# July         5035299
# June         4184770
# May          3529893
# April        2436111
# March        1813960
# February      956348
# January       408213
# Name: mb_used, dtype: int64

# %% [markdown]
# Довольно явное увеличение трафика с января по декабрь. И снова - самые загруженные месяцы: октябрь, ноябрь и декабрь.

# %% [markdown]
# ### Таблица messages

# %% [markdown]
# #### Замена типа данных

# %%
# переведем тип данных столбца 'message_date' в  datetime

messages['message_date'] = pd.to_datetime(messages['message_date'], format = '%Y-%m-%d')

# %%
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  datetime64[ns]
#  2   user_id       123036 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# #### Подсчет количества отправленных сообщений по месяцам

# %%
# добавим новый столбец с названием месяца 

messages['month'] = messages['message_date'].dt.month_name()

# %%
# посчитаем количество отправленных смс по месяцам 

messages_per_month = messages['month'].value_counts()
messages_per_month
# Out:
# December     20555
# November     18244
# October      17114
# September    14759
# August       13088
# July         11320
# June          8983
# May           7298
# April         5179
# March         3648
# February      1924
# January        924
# Name: month, dtype: int64

# %% [markdown]
# Все в точности, как и с остальными параметрами - увеличение от января к декабрю.

# %% [markdown]
# ### Таблица tariffs

# %%
# переименуем столбец с названиями тарифов
tariffs = tariffs.rename(columns = {'tariff_name': 'tariff'})

# %% [markdown]
# ### Подсчет помесячной выручки с каждого пользователя

# %%
# создадим сводную таблицу по звонкам для каждого user_id и месяца

calls_by_month_users = calls.pivot_table(index=['user_id', 'month'],  values=['duration'], aggfunc='sum').reset_index()
calls_by_month_users.head()
# Out:
#    user_id     month  duration
# 0     1000    August       408
# 1     1000  December       333
# 2     1000      July       340
# 3     1000      June       172
# 4     1000       May       159

# %%
# создадим сводную таблицу по сообщениям для каждого user_id и месяца

messages_by_month_users = messages.pivot_table(index=['user_id', 'month'],  values=['id'], aggfunc='count').reset_index()
messages_by_month_users.head()
# Out:
#    user_id     month  id
# 0     1000    August  81
# 1     1000  December  70
# 2     1000      July  75
# 3     1000      June  60
# 4     1000       May  22

# %%
# создадим сводную таблицу по потраченным мб для каждого user_id и месяца

internet_by_month_users = internet.pivot_table(index=['user_id', 'month'], \
                                               values=['mb_used'], aggfunc='sum').reset_index()
internet_by_month_users.head()
# Out:
#    user_id     month  mb_used
# 0     1000    August    14070
# 1     1000  December     9827
# 2     1000      July    14016
# 3     1000      June    23257
# 4     1000       May     2256

# %%
# создадим временную таблицу путем объединения таблиц с данными о количестве минут, смс и мб

temp = reduce(lambda left,right: pd.merge(left, right, \
                                             on=['user_id', 'month'], how='outer'), \
                 [calls_by_month_users, messages_by_month_users, internet_by_month_users])

temp.head()
# Out:
#    user_id     month  duration    id  mb_used
# 0     1000    August    408.00 81.00 14070.00
# 1     1000  December    333.00 70.00  9827.00
# 2     1000      July    340.00 75.00 14016.00
# 3     1000      June    172.00 60.00 23257.00
# 4     1000       May    159.00 22.00  2256.00

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Крутейшее объединение через <code>reduce</code> 🔥🔥🔥</div> <br>
# <div style="border:solid red 2px; padding: 20px"> <b>Что необходимо доработать</b><br>
# Есть маленькая ошибка в объединении, так как в каждой таблице может не быть всех пользователей из других, то объединять нужно с параметром <code>how='outer'</code> - чтобы в результирующей таблице были все клиенты</div><br>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Точно. Поправил.
#
#
# </div>
#
# ---

# %%
temp = temp.rename(columns={'duration':'minutes', 'id':'messages'})
temp.head()
# Out:
#    user_id     month  minutes  messages  mb_used
# 0     1000    August   408.00     81.00 14070.00
# 1     1000  December   333.00     70.00  9827.00
# 2     1000      July   340.00     75.00 14016.00
# 3     1000      June   172.00     60.00 23257.00
# 4     1000       May   159.00     22.00  2256.00

# %%
# создадим временную таблицу путем объединения таблиц users и tariffs 

temp_2 = pd.merge(users, tariffs, on='tariff', how='left')
temp_2.head()
# Out:
#    user_id  age churn_date         city first_name  last_name   reg_date  \
# 0     1000   52        NaT    Краснодар     Рафаил  Верещагин 2018-05-25
# 1     1001   41        NaT       Москва       Иван       Ежов 2018-11-01
# 2     1002   59        NaT  Стерлитамак    Евгений  Абрамович 2018-06-17
# 3     1003   23        NaT       Москва      Белла   Белякова 2018-08-17
# 4     1004   68        NaT  Новокузнецк    Татьяна   Авдеенко 2018-05-14
#
#   tariff  messages_included  mb_per_month_included  minutes_included  \
# 0  ultra               1000                  30720              3000
# 1  smart                 50                  15360               500
# 2  smart                 50                  15360               500
# 3  ultra               1000                  30720              3000
# 4  ultra               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute
# 0             1950         150                1               1
# 1              550         200                3               3
# 2              550         200                3               3
# 3             1950         150                1               1
# 4             1950         150                1               1

# %%
# объединяем две временные таблицы и получаем большой сводный датафрейм 

all_in_one = pd.merge(temp, temp_2, on='user_id', how='outer')
all_in_one.head()
# Out:
#    user_id     month  minutes  messages  mb_used  age churn_date       city  \
# 0     1000    August   408.00     81.00 14070.00   52        NaT  Краснодар
# 1     1000  December   333.00     70.00  9827.00   52        NaT  Краснодар
# 2     1000      July   340.00     75.00 14016.00   52        NaT  Краснодар
# 3     1000      June   172.00     60.00 23257.00   52        NaT  Краснодар
# 4     1000       May   159.00     22.00  2256.00   52        NaT  Краснодар
#
#   first_name  last_name   reg_date tariff  messages_included  \
# 0     Рафаил  Верещагин 2018-05-25  ultra               1000
# 1     Рафаил  Верещагин 2018-05-25  ultra               1000
# 2     Рафаил  Верещагин 2018-05-25  ultra               1000
# 3     Рафаил  Верещагин 2018-05-25  ultra               1000
# 4     Рафаил  Верещагин 2018-05-25  ultra               1000
#
#    mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# 0                  30720              3000             1950         150
# 1                  30720              3000             1950         150
# 2                  30720              3000             1950         150
# 3                  30720              3000             1950         150
# 4                  30720              3000             1950         150
#
#    rub_per_message  rub_per_minute
# 0                1               1
# 1                1               1
# 2                1               1
# 3                1               1
# 4                1               1

# %% [markdown]
# Создадим ряд функций для рассчета превышений по тарифам

# %%
# функция для подсчета минут сверх тарифа

def minutes_over_tariff(row):
    if row['tariff'] == 'smart':
        result = row['minutes'] - 500
        return np.where(result > 0, result, 0)
    else:
        result = row['minutes'] - 3000
        return np.where(result > 0, result, 0)
    

# функция для подсчета смс сверх тарифа   

def messages_over_tariff(row):
    if row['tariff'] == 'smart':
        result = row['messages'] - 50
        return np.where(result > 0, result, 0)
    else:
        result =  row['messages'] - 1000
        return np.where(result > 0, result, 0)
    

# функция для подсчета мб сверх тарифа   

def internet_over_tariff(row):
    if row['tariff'] == 'smart':
        result = row['mb_used'] - 15360
        return np.where(result > 0, result, 0)
    else:
        result = row['mb_used'] - 30720
        return np.where(result > 0, result, 0)
    
    
    
# функция для подсчета прибыли сверх абонентской платы 

def month_profit(row):
    sum_per_month = 0
    if row['tariff'] == 'smart':
        sum_per_month += np.ceil(row['minutes_over']) * 3
        sum_per_month += row['messages_over'] * 3
        sum_per_month += np.ceil(row['mb_over']/1024) * 200
        return sum_per_month
    
    else:
        sum_per_month += np.ceil(row['minutes_over']) * 1
        sum_per_month += row['messages_over'] * 1
        sum_per_month += np.ceil(row['mb_over']/1024) * 150
        return sum_per_month

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
# Так здорово собрал все данные в одной таблице, чтобы ручками подставлять значения ?! Зачем если, они записаны в столбцах, выполняй операции над столбцами и ничего не надо подставлять (пример ниже)</div> <br>

# %%
all_in_one\
    .assign(sms_payment = lambda row: np.where(row['messages'] - \
                                               row['messages_included'] > 0, \
                                               row['messages'] - row['messages_included'], 0) * \
            row['rub_per_message'])
# Out:
#       user_id      month  minutes  messages  mb_used  age churn_date  \
# 0        1000     August   408.00     81.00 14070.00   52        NaT
# 1        1000   December   333.00     70.00  9827.00   52        NaT
# 2        1000       July   340.00     75.00 14016.00   52        NaT
# 3        1000       June   172.00     60.00 23257.00   52        NaT
# 4        1000        May   159.00     22.00  2256.00   52        NaT
# ...       ...        ...      ...       ...      ...  ...        ...
# 3211     1489   November      NaN     20.00 17516.00   35        NaT
# 3212     1489    October      NaN     21.00 19588.00   35        NaT
# 3213     1489  September      NaN     32.00 17232.00   35        NaT
# 3214     1128        NaN      NaN       NaN      NaN   51 2018-12-23
# 3215     1371        NaN      NaN       NaN      NaN   50 2018-12-30
#
#                  city first_name  last_name   reg_date tariff  \
# 0           Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 1           Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 2           Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 3           Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# 4           Краснодар     Рафаил  Верещагин 2018-05-25  ultra
# ...               ...        ...        ...        ...    ...
# 3211  Санкт-Петербург      Павел   Гончаров 2018-08-15  smart
# 3212  Санкт-Петербург      Павел   Гончаров 2018-08-15  smart
# 3213  Санкт-Петербург      Павел   Гончаров 2018-08-15  smart
# 3214         Волжский     Ксения     Агаева 2018-12-15  ultra
# 3215             Омск     Ириней   Трофимов 2018-12-25  smart
#
#       messages_included  mb_per_month_included  minutes_included  \
# 0                  1000                  30720              3000
# 1                  1000                  30720              3000
# 2                  1000                  30720              3000
# 3                  1000                  30720              3000
# 4                  1000                  30720              3000
# ...                 ...                    ...               ...
# 3211                 50                  15360               500
# 3212                 50                  15360               500
# 3213                 50                  15360               500
# 3214               1000                  30720              3000
# 3215                 50                  15360               500
#
#       rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# 0                1950         150                1               1
# 1                1950         150                1               1
# 2                1950         150                1               1
# 3                1950         150                1               1
# 4                1950         150                1               1
# ...               ...         ...              ...             ...
# 3211              550         200                3               3
# 3212              550         200                3               3
# 3213              550         200                3               3
# 3214             1950         150                1               1
# 3215              550         200                3               3
#
#       sms_payment
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            0.00
# ...           ...
# 3211         0.00
# 3212         0.00
# 3213         0.00
# 3214         0.00
# 3215         0.00
#
# [3216 rows x 20 columns]

# %% [markdown]
# <hr style="border: 2px solid orange;" />

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Благодарю. Обязательно воспользуюсь рекомендацией. В данном случае - согласен, можно было и сократить.
#
#
# </div>
#
# ---

# %%
# создадим новые столбцы с данными по превышению 

all_in_one['minutes_over'] = all_in_one.apply(minutes_over_tariff, axis=1).astype(int)
all_in_one['messages_over'] = all_in_one.apply(messages_over_tariff, axis=1).astype(int)
all_in_one['mb_over'] = all_in_one.apply(internet_over_tariff, axis=1).astype(int)

# создаем столбец с суммой дохода сверх тарифа 
all_in_one['over_profit'] = all_in_one.apply(month_profit, axis=1)


# создадим столбец с общей суммой затрат 

all_in_one['total_profit'] = all_in_one['rub_monthly_fee'] + all_in_one['over_profit']
all_in_one.sample(5)
# Out:
#       user_id     month  minutes  messages  mb_used  age churn_date  \
# 670      1108  November   231.00     25.00 20427.00   70        NaT
# 458      1072    August   439.00     24.00 28327.00   49        NaT
# 161      1025     April   464.00     27.00 10461.00   56        NaT
# 200      1032     April   521.00     30.00 16869.00   31        NaT
# 2581     1407  November   239.00     28.00 11343.00   40        NaT
#
#            city first_name  last_name   reg_date tariff  messages_included  \
# 670      Москва     Рафаил   Болдырев 2018-11-01  smart                 50
# 458         Уфа     Андрей  Андрейкин 2018-02-20  smart                 50
# 161         Уфа     Матвей     Акинин 2018-03-15  smart                 50
# 200   Ульяновск       Инна  Игнатьева 2018-01-04  smart                 50
# 2581  Челябинск       Элла   Пирогова 2018-08-14  smart                 50
#
#       mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# 670                   15360               500              550         200
# 458                   15360               500              550         200
# 161                   15360               500              550         200
# 200                   15360               500              550         200
# 2581                  15360               500              550         200
#
#       rub_per_message  rub_per_minute  minutes_over  messages_over  mb_over  \
# 670                 3               3             0              0     5067
# 458                 3               3             0              0    12967
# 161                 3               3             0              0        0
# 200                 3               3            21              0     1509
# 2581                3               3             0              0        0
#
#       over_profit  total_profit
# 670       1000.00       1550.00
# 458       2600.00       3150.00
# 161          0.00        550.00
# 200        463.00       1013.00
# 2581         0.00        550.00

# %% [markdown]
# ### Выводы

# %% [markdown]
# - была создана общая таблица, объединяющая всех клиентов и их поведение по месяцам.
# - посчитано и добавлено в таблицу:
#    - количество минут свех тарифа
#    - количество сообщений сверх тарифа
#    - количество мб серх тарифа
#    - сумма переплат по каждому клиенту (если имеется)
#    - общая расходов по каждому клиенту

# %% [markdown]
# ## Шаг 3. Анализ данных

# %% [markdown]
# ### Описание поведения клиентов оператора, исходя из выборки

# %% [markdown]
# #### Процент клиентов с расходами сверх абонентской платы

# %% [markdown]
# Для начала посмотрим какой процент клиентов того или иного тарифа переплачивают за услуги (то есть тратят больше обязательного ежемесячного платежа).

# %%
# посчитаем процент клиентов тарифа Smart, покупающих доп услуги 

len(all_in_one.query('tariff == "smart" and over_profit > 0'))/len(all_in_one.query('tariff == "smart"'))*100
# Out:
# 74.66367713004485

# %% [markdown]
# Почти 75% клиентов на тарифе Smart регулярно доплачивают. Явно не хватает включенных в тариф услуг.

# %%
# посмотрим данные по клиентам тарифа ultra, которые переплачивают 

len(all_in_one.query('tariff == "ultra" and over_profit > 0')) / len(all_in_one.query('tariff == "ultra"'))*100
# Out:
# 13.590263691683571

# %% [markdown]
# Всего 13% клиентов тарифа Ultra тратят больше обязательного платежа.

# %% [markdown]
# #### Выводы

# %% [markdown]
# Пользователи тарифа Smart гораздо чаще докупают дополнительные пакеты услуг по сравнений с пользователями тарифа Ultra.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Отличная проверка 👍</div> <br>

# %% [markdown]
# ### Детальное рассмотрение тарифов

# %% [markdown]
# #### Тариф Smart

# %%
# создадим таблицу только с данными по тарифу Smart

smart_only = all_in_one[all_in_one['tariff']=='smart']
smart_only.sample(5, random_state=0)
# Out:
#       user_id      month  minutes  messages  mb_used  age churn_date  \
# 190      1030     August   426.00     97.00 12193.00   28        NaT
# 874      1142  September   465.00     33.00 13135.00   51        NaT
# 60       1007    October   465.00     18.00 14444.00   65        NaT
# 1891     1302     August   182.00     82.00 19653.00   43        NaT
# 460      1072   February   137.00      5.00  4884.00   49        NaT
#
#              city first_name  last_name   reg_date tariff  messages_included  \
# 190     Махачкала   Мариетта   Русанова 2018-05-23  smart                 50
# 874   Новосибирск     Симона   Алешкова 2018-03-24  smart                 50
# 60         Москва        Юна   Березина 2018-04-19  smart                 50
# 1891          Уфа  Владислав    Абаимов 2018-01-23  smart                 50
# 460           Уфа     Андрей  Андрейкин 2018-02-20  smart                 50
#
#       mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# 190                   15360               500              550         200
# 874                   15360               500              550         200
# 60                    15360               500              550         200
# 1891                  15360               500              550         200
# 460                   15360               500              550         200
#
#       rub_per_message  rub_per_minute  minutes_over  messages_over  mb_over  \
# 190                 3               3             0             47        0
# 874                 3               3             0              0        0
# 60                  3               3             0              0        0
# 1891                3               3             0             32     4293
# 460                 3               3             0              0        0
#
#       over_profit  total_profit
# 190        141.00        691.00
# 874          0.00        550.00
# 60           0.00        550.00
# 1891      1096.00       1646.00
# 460          0.00        550.00

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
# При использовании метода <code>df.sample(N)</code> - отображается N случайных строк из датасета. Дело в том, что их индексы генерируются случайно, а ты можешь увидеть что-то необычное в данных (аномалии\выбросы\некие особенности), но при последующем запуске повторения не будет. Для того, чтобы результаты были повторяемыми есть параметр <code>random_state</code> - если его задать, то результат всегда будет одним и тем же. Сравни примеры кода ниже
# </div> <br>

# %%
display(pd.concat([smart_only.sample(1) for _ in range(3)])\
    .style\
    .set_caption('Without random_state'))
	
display(pd.concat([smart_only.sample(1, random_state=0) for _ in range(3)])\
    .reset_index(drop=True)\
    .style\
    .set_caption('With random_state'))
# Out:
# <style  type="text/css" >
# </style><table id="T_1b88d_" ><caption>Without random_state</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >month</th>        <th class="col_heading level0 col2" >minutes</th>        <th class="col_heading level0 col3" >messages</th>        <th class="col_heading level0 col4" >mb_used</th>        <th class="col_heading level0 col5" >age</th>        <th class="col_heading level0 col6" >churn_date</th>        <th class="col_heading level0 col7" >city</th>        <th class="col_heading level0 col8" >first_name</th>        <th class="col_heading level0 col9" >last_name</th>        <th class="col_heading level0 col10" >reg_date</th>        <th class="col_heading level0 col11" >tariff</th>        <th class="col_heading level0 col12" >messages_included</th>        <th class="col_heading level0 col13" >mb_per_month_included</th>        <th class="col_heading level0 col14" >minutes_included</th>        <th class="col_heading level0 col15" >rub_monthly_fee</th>        <th class="col_heading level0 col16" >rub_per_gb</th>        <th class="col_heading level0 col17" >rub_per_message</th>        <th class="col_heading level0 col18" >rub_per_minute</th>        <th class="col_heading level0 col19" >minutes_over</th>        <th class="col_heading level0 col20" >messages_over</th>        <th class="col_heading level0 col21" >mb_over</th>        <th class="col_heading level0 col22" >over_profit</th>        <th class="col_heading level0 col23" >total_profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b88d_level0_row0" class="row_heading level0 row0" >2238</th>
#                         <td id="T_1b88d_row0_col0" class="data row0 col0" >1359</td>
#                         <td id="T_1b88d_row0_col1" class="data row0 col1" >August</td>
#                         <td id="T_1b88d_row0_col2" class="data row0 col2" >681.000000</td>
#                         <td id="T_1b88d_row0_col3" class="data row0 col3" >18.000000</td>
#                         <td id="T_1b88d_row0_col4" class="data row0 col4" >11453.000000</td>
#                         <td id="T_1b88d_row0_col5" class="data row0 col5" >52</td>
#                         <td id="T_1b88d_row0_col6" class="data row0 col6" >NaT</td>
#                         <td id="T_1b88d_row0_col7" class="data row0 col7" >Москва</td>
#                         <td id="T_1b88d_row0_col8" class="data row0 col8" >Константин</td>
#                         <td id="T_1b88d_row0_col9" class="data row0 col9" >Абашкин</td>
#                         <td id="T_1b88d_row0_col10" class="data row0 col10" >2018-07-27 00:00:00</td>
#                         <td id="T_1b88d_row0_col11" class="data row0 col11" >smart</td>
#                         <td id="T_1b88d_row0_col12" class="data row0 col12" >50</td>
#                         <td id="T_1b88d_row0_col13" class="data row0 col13" >15360</td>
#                         <td id="T_1b88d_row0_col14" class="data row0 col14" >500</td>
#                         <td id="T_1b88d_row0_col15" class="data row0 col15" >550</td>
#                         <td id="T_1b88d_row0_col16" class="data row0 col16" >200</td>
#                         <td id="T_1b88d_row0_col17" class="data row0 col17" >3</td>
#                         <td id="T_1b88d_row0_col18" class="data row0 col18" >3</td>
#                         <td id="T_1b88d_row0_col19" class="data row0 col19" >181</td>
#                         <td id="T_1b88d_row0_col20" class="data row0 col20" >0</td>
#                         <td id="T_1b88d_row0_col21" class="data row0 col21" >0</td>
#                         <td id="T_1b88d_row0_col22" class="data row0 col22" >543.000000</td>
#                         <td id="T_1b88d_row0_col23" class="data row0 col23" >1093.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b88d_level0_row1" class="row_heading level0 row1" >897</th>
#                         <td id="T_1b88d_row1_col0" class="data row1 col0" >1145</td>
#                         <td id="T_1b88d_row1_col1" class="data row1 col1" >June</td>
#                         <td id="T_1b88d_row1_col2" class="data row1 col2" >397.000000</td>
#                         <td id="T_1b88d_row1_col3" class="data row1 col3" >99.000000</td>
#                         <td id="T_1b88d_row1_col4" class="data row1 col4" >13006.000000</td>
#                         <td id="T_1b88d_row1_col5" class="data row1 col5" >45</td>
#                         <td id="T_1b88d_row1_col6" class="data row1 col6" >NaT</td>
#                         <td id="T_1b88d_row1_col7" class="data row1 col7" >Тюмень</td>
#                         <td id="T_1b88d_row1_col8" class="data row1 col8" >Юлий</td>
#                         <td id="T_1b88d_row1_col9" class="data row1 col9" >Алешин</td>
#                         <td id="T_1b88d_row1_col10" class="data row1 col10" >2018-04-11 00:00:00</td>
#                         <td id="T_1b88d_row1_col11" class="data row1 col11" >smart</td>
#                         <td id="T_1b88d_row1_col12" class="data row1 col12" >50</td>
#                         <td id="T_1b88d_row1_col13" class="data row1 col13" >15360</td>
#                         <td id="T_1b88d_row1_col14" class="data row1 col14" >500</td>
#                         <td id="T_1b88d_row1_col15" class="data row1 col15" >550</td>
#                         <td id="T_1b88d_row1_col16" class="data row1 col16" >200</td>
#                         <td id="T_1b88d_row1_col17" class="data row1 col17" >3</td>
#                         <td id="T_1b88d_row1_col18" class="data row1 col18" >3</td>
#                         <td id="T_1b88d_row1_col19" class="data row1 col19" >0</td>
#                         <td id="T_1b88d_row1_col20" class="data row1 col20" >49</td>
#                         <td id="T_1b88d_row1_col21" class="data row1 col21" >0</td>
#                         <td id="T_1b88d_row1_col22" class="data row1 col22" >147.000000</td>
#                         <td id="T_1b88d_row1_col23" class="data row1 col23" >697.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_1b88d_level0_row2" class="row_heading level0 row2" >1406</th>
#                         <td id="T_1b88d_row2_col0" class="data row2 col0" >1224</td>
#                         <td id="T_1b88d_row2_col1" class="data row2 col1" >December</td>
#                         <td id="T_1b88d_row2_col2" class="data row2 col2" >705.000000</td>
#                         <td id="T_1b88d_row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_1b88d_row2_col4" class="data row2 col4" >24483.000000</td>
#                         <td id="T_1b88d_row2_col5" class="data row2 col5" >58</td>
#                         <td id="T_1b88d_row2_col6" class="data row2 col6" >NaT</td>
#                         <td id="T_1b88d_row2_col7" class="data row2 col7" >Магнитогорск</td>
#                         <td id="T_1b88d_row2_col8" class="data row2 col8" >Ахмет</td>
#                         <td id="T_1b88d_row2_col9" class="data row2 col9" >Тарасов</td>
#                         <td id="T_1b88d_row2_col10" class="data row2 col10" >2018-04-24 00:00:00</td>
#                         <td id="T_1b88d_row2_col11" class="data row2 col11" >smart</td>
#                         <td id="T_1b88d_row2_col12" class="data row2 col12" >50</td>
#                         <td id="T_1b88d_row2_col13" class="data row2 col13" >15360</td>
#                         <td id="T_1b88d_row2_col14" class="data row2 col14" >500</td>
#                         <td id="T_1b88d_row2_col15" class="data row2 col15" >550</td>
#                         <td id="T_1b88d_row2_col16" class="data row2 col16" >200</td>
#                         <td id="T_1b88d_row2_col17" class="data row2 col17" >3</td>
#                         <td id="T_1b88d_row2_col18" class="data row2 col18" >3</td>
#                         <td id="T_1b88d_row2_col19" class="data row2 col19" >205</td>
#                         <td i
# <style  type="text/css" >
# </style><table id="T_3e13e_" ><caption>With random_state</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >month</th>        <th class="col_heading level0 col2" >minutes</th>        <th class="col_heading level0 col3" >messages</th>        <th class="col_heading level0 col4" >mb_used</th>        <th class="col_heading level0 col5" >age</th>        <th class="col_heading level0 col6" >churn_date</th>        <th class="col_heading level0 col7" >city</th>        <th class="col_heading level0 col8" >first_name</th>        <th class="col_heading level0 col9" >last_name</th>        <th class="col_heading level0 col10" >reg_date</th>        <th class="col_heading level0 col11" >tariff</th>        <th class="col_heading level0 col12" >messages_included</th>        <th class="col_heading level0 col13" >mb_per_month_included</th>        <th class="col_heading level0 col14" >minutes_included</th>        <th class="col_heading level0 col15" >rub_monthly_fee</th>        <th class="col_heading level0 col16" >rub_per_gb</th>        <th class="col_heading level0 col17" >rub_per_message</th>        <th class="col_heading level0 col18" >rub_per_minute</th>        <th class="col_heading level0 col19" >minutes_over</th>        <th class="col_heading level0 col20" >messages_over</th>        <th class="col_heading level0 col21" >mb_over</th>        <th class="col_heading level0 col22" >over_profit</th>        <th class="col_heading level0 col23" >total_profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3e13e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3e13e_row0_col0" class="data row0 col0" >1030</td>
#                         <td id="T_3e13e_row0_col1" class="data row0 col1" >August</td>
#                         <td id="T_3e13e_row0_col2" class="data row0 col2" >426.000000</td>
#                         <td id="T_3e13e_row0_col3" class="data row0 col3" >97.000000</td>
#                         <td id="T_3e13e_row0_col4" class="data row0 col4" >12193.000000</td>
#                         <td id="T_3e13e_row0_col5" class="data row0 col5" >28</td>
#                         <td id="T_3e13e_row0_col6" class="data row0 col6" >NaT</td>
#                         <td id="T_3e13e_row0_col7" class="data row0 col7" >Махачкала</td>
#                         <td id="T_3e13e_row0_col8" class="data row0 col8" >Мариетта</td>
#                         <td id="T_3e13e_row0_col9" class="data row0 col9" >Русанова</td>
#                         <td id="T_3e13e_row0_col10" class="data row0 col10" >2018-05-23 00:00:00</td>
#                         <td id="T_3e13e_row0_col11" class="data row0 col11" >smart</td>
#                         <td id="T_3e13e_row0_col12" class="data row0 col12" >50</td>
#                         <td id="T_3e13e_row0_col13" class="data row0 col13" >15360</td>
#                         <td id="T_3e13e_row0_col14" class="data row0 col14" >500</td>
#                         <td id="T_3e13e_row0_col15" class="data row0 col15" >550</td>
#                         <td id="T_3e13e_row0_col16" class="data row0 col16" >200</td>
#                         <td id="T_3e13e_row0_col17" class="data row0 col17" >3</td>
#                         <td id="T_3e13e_row0_col18" class="data row0 col18" >3</td>
#                         <td id="T_3e13e_row0_col19" class="data row0 col19" >0</td>
#                         <td id="T_3e13e_row0_col20" class="data row0 col20" >47</td>
#                         <td id="T_3e13e_row0_col21" class="data row0 col21" >0</td>
#                         <td id="T_3e13e_row0_col22" class="data row0 col22" >141.000000</td>
#                         <td id="T_3e13e_row0_col23" class="data row0 col23" >691.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e13e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3e13e_row1_col0" class="data row1 col0" >1030</td>
#                         <td id="T_3e13e_row1_col1" class="data row1 col1" >August</td>
#                         <td id="T_3e13e_row1_col2" class="data row1 col2" >426.000000</td>
#                         <td id="T_3e13e_row1_col3" class="data row1 col3" >97.000000</td>
#                         <td id="T_3e13e_row1_col4" class="data row1 col4" >12193.000000</td>
#                         <td id="T_3e13e_row1_col5" class="data row1 col5" >28</td>
#                         <td id="T_3e13e_row1_col6" class="data row1 col6" >NaT</td>
#                         <td id="T_3e13e_row1_col7" class="data row1 col7" >Махачкала</td>
#                         <td id="T_3e13e_row1_col8" class="data row1 col8" >Мариетта</td>
#                         <td id="T_3e13e_row1_col9" class="data row1 col9" >Русанова</td>
#                         <td id="T_3e13e_row1_col10" class="data row1 col10" >2018-05-23 00:00:00</td>
#                         <td id="T_3e13e_row1_col11" class="data row1 col11" >smart</td>
#                         <td id="T_3e13e_row1_col12" class="data row1 col12" >50</td>
#                         <td id="T_3e13e_row1_col13" class="data row1 col13" >15360</td>
#                         <td id="T_3e13e_row1_col14" class="data row1 col14" >500</td>
#                         <td id="T_3e13e_row1_col15" class="data row1 col15" >550</td>
#                         <td id="T_3e13e_row1_col16" class="data row1 col16" >200</td>
#                         <td id="T_3e13e_row1_col17" class="data row1 col17" >3</td>
#                         <td id="T_3e13e_row1_col18" class="data row1 col18" >3</td>
#                         <td id="T_3e13e_row1_col19" class="data row1 col19" >0</td>
#                         <td id="T_3e13e_row1_col20" class="data row1 col20" >47</td>
#                         <td id="T_3e13e_row1_col21" class="data row1 col21" >0</td>
#                         <td id="T_3e13e_row1_col22" class="data row1 col22" >141.000000</td>
#                         <td id="T_3e13e_row1_col23" class="data row1 col23" >691.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_3e13e_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3e13e_row2_col0" class="data row2 col0" >1030</td>
#                         <td id="T_3e13e_row2_col1" class="data row2 col1" >August</td>
#                         <td id="T_3e13e_row2_col2" class="data row2 col2" >426.000000</td>
#                         <td id="T_3e13e_row2_col3" class="data row2 col3" >97.000000</td>
#                         <td id="T_3e13e_row2_col4" class="data row2 col4" >12193.000000</td>
#                         <td id="T_3e13e_row2_col5" class="data row2 col5" >28</td>
#                         <td id="T_3e13e_row2_col6" class="data row2 col6" >NaT</td>
#                         <td id="T_3e13e_row2_col7" class="data row2 col7" >Махачкала</td>
#                         <td id="T_3e13e_row2_col8" class="data row2 col8" >Мариетта</td>
#                         <td id="T_3e13e_row2_col9" class="data row2 col9" >Русанова</td>
#                         <td id="T_3e13e_row2_col10" class="data row2 col10" >2018-05-23 00:00:00</td>
#                         <td id="T_3e13e_row2_col11" class="data row2 col11" >smart</td>
#                         <td id="T_3e13e_row2_col12" class="data row2 col12" >50</td>
#                         <td id="T_3e13e_row2_col13" class="data row2 col13" >15360</td>
#                         <td id="T_3e13e_row2_col14" class="data row2 col14" >500</td>
#                         <td id="T_3e13e_row2_col15" class="data row2 col15" >550</td>
#                         <td id="T_3e13e_row2_col16" class="data row2 col16" >200</td>
#                         <td id="T_3e13e_row2_col17" class="data row2 col17" >3</td>
#                         <td id="T_3e13e_row2_col18" class="data row2 col18" >3</td>
#                         <td id="T_3e13e_row2_col19" class="data row2 col19" >0</td>
#                         <t

# %% [markdown]
# <hr style="border: 2px solid orange;" />

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Отлично! Благодарю. Буду пользоваться. В данном случае я просто заменил стандартный вывод с .head() на .sample().
#
#
# </div>
#
# ---

# %%
# выведем данные по тарифу Smart 

smart_only[['minutes', 'messages', 'mb_used', \
            'minutes_over', 'messages_over', 'mb_over', 'total_profit']].describe()
# Out:
#        minutes  messages  mb_used  minutes_over  messages_over  mb_over  \
# count  2221.00   1922.00  2227.00       2230.00        2230.00  2230.00
# mean    419.44     38.72 16243.76         41.59           5.80  2769.36
# std     188.99     26.79  5860.04         84.66          13.44  3604.04
# min       2.00      1.00   202.00          0.00           0.00     0.00
# 25%     285.00     17.00 12677.00          0.00           0.00     0.00
# 50%     423.00     34.00 16533.00          0.00           0.00  1169.00
# 75%     546.00     55.00 20068.00         45.00           1.00  4708.00
# max    1435.00    143.00 38610.00        935.00          93.00 23250.00
#
#        total_profit
# count       2230.00
# mean        1294.31
# std          820.90
# min          550.00
# 25%          550.00
# 50%         1037.00
# 75%         1750.00
# max         6770.00

# %% [markdown]
# В среднем абоненты тарифа Smart:
# - тратят ~420 минут
# - отправляют ~39 сообщений
# - тратят почти ~16 Гб мобильного интернета
# - превышают пакет минут на ~42 минуты
# - превышают пакет сообщений на ~6
# - превышают пакет интернета на ~2.7 Гб
#
#
# Стандартное отконение:
# - по количеству потраченных минут составляет ~189
# - по количеству отправленных смс составляет ~27
# - по количеству потраченных мб ~5866

# %%
# посчитаем дисперсию для данных тарифа Smart 

(smart_only[['minutes', 'messages', 'mb_used', \
            'minutes_over', 'messages_over', 'mb_over', 'total_profit']] \
 .describe().T['std'] ** 2).to_frame(name='Дисперсия')
# Out:
#                 Дисперсия
# minutes          35718.13
# messages           717.59
# mb_used       34340091.55
# minutes_over      7168.02
# messages_over      180.63
# mb_over       12989113.32
# total_profit    673877.62

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
# Чтобы не писать много кода =)</div> <br>

# %%
#(smart_only[['minutes', 'messages', 'mb_used', \
#            'minutes_over', 'messages_over', 'mb_over', 'total_profit']].describe().T['std'] ** 2).to_frame(name='Дисперсия')

# %% [markdown]
# <hr style="border: 2px solid orange;" />

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Благодарю! Воспользовался и передал дальше.
#
#
# </div>
#
# ---

# %%
# построим графики распределения для основных данных тарифа Smart: минуты, смс и мб 

pd.plotting.scatter_matrix(smart_only[['minutes', 'messages', \
                                       'mb_used', 'total_profit']], \
                           alpha = 0.2, figsize = (14,10))
plt.show()

# %% [markdown]
# Количество сообщений имеют распределение Пуассона.
#
# Количество минут и потраченных мб - распределение Гаусса.

# %% [markdown]
# #### Тариф Ultra

# %%
# создадим таблицу только с данными по тарифу Ultra

ultra_only = all_in_one[all_in_one['tariff']=='ultra']
ultra_only.sample(5)
# Out:
#       user_id      month  minutes  messages  mb_used  age churn_date  \
# 2639     1415  September   764.00     40.00 36910.00   41        NaT
# 1271     1201   November   886.00       NaN  7937.00   32 2018-12-03
# 1804     1289    October  1053.00     71.00 17802.00   20        NaT
# 3208     1473  September      NaN     19.00 17307.00   18        NaT
# 2246     1360   December   825.00       NaN  7523.00   46        NaT
#
#                  city first_name  last_name   reg_date tariff  \
# 2639           Москва     Андрей      Лукин 2018-06-29  ultra
# 1271           Москва   Геннадий    Веселов 2018-08-06  ultra
# 1804           Москва     Таисия  Богданова 2018-09-01  ultra
# 3208       Красноярск    Николай    Лебедев 2018-08-05  ultra
# 2246  Санкт-Петербург      Лаура   Макарова 2018-03-18  ultra
#
#       messages_included  mb_per_month_included  minutes_included  \
# 2639               1000                  30720              3000
# 1271               1000                  30720              3000
# 1804               1000                  30720              3000
# 3208               1000                  30720              3000
# 2246               1000                  30720              3000
#
#       rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# 2639             1950         150                1               1
# 1271             1950         150                1               1
# 1804             1950         150                1               1
# 3208             1950         150                1               1
# 2246             1950         150                1               1
#
#       minutes_over  messages_over  mb_over  over_profit  total_profit
# 2639             0              0     6190      1050.00       3000.00
# 1271             0              0        0         0.00       1950.00
# 1804             0              0        0         0.00       1950.00
# 3208             0              0        0         0.00       1950.00
# 2246             0              0        0         0.00       1950.00

# %%
# выведем данные по тарифу Ultra 

ultra_only[['minutes', 'messages', 'mb_used', \
            'minutes_over', 'messages_over', 'mb_over', 'total_profit']].describe()
# Out:
#        minutes  messages  mb_used  minutes_over  messages_over  mb_over  \
# count   947.00    795.00   974.00        986.00         986.00   986.00
# mean    547.76     61.16 19706.98          0.00           0.00   753.79
# std     305.51     45.93  9937.13          0.00           0.00  2431.26
# min       1.00      1.00   366.00          0.00           0.00     0.00
# 25%     311.00     24.00 12073.75          0.00           0.00     0.00
# 50%     529.00     51.00 19427.50          0.00           0.00     0.00
# 75%     758.00     87.50 26936.25          0.00           0.00     0.00
# max    1673.00    224.00 49789.00          0.00           0.00 19069.00
#
#        total_profit
# count        986.00
# mean        2070.94
# std          378.63
# min         1950.00
# 25%         1950.00
# 50%         1950.00
# 75%         1950.00
# max         4800.00

# %% [markdown]
# В среднем абоненты тарифа Ultra:
# - тратят ~548 минут
# - отправляют ~61 сообщение
# - тратят почти ~19 Гб мобильного интернета
# - не превышают пакет минут
# - не превышают пакет сообщений
# - превышают пакет интернета на ~760 Мб
#
#
# Стандартное отконение:
# - по количеству потраченных минут составляет ~189
# - по количеству отправленных смс составляет ~27
# - по количеству потраченных мб ~5866

# %%
# посчитаем дисперсию для основных параметров

(ultra_only[['minutes', 'messages', 'mb_used', \
            'minutes_over', 'messages_over', 'mb_over', 'total_profit']] \
 .describe().T['std'] ** 2).to_frame(name='Дисперсия')
# Out:
#                 Дисперсия
# minutes          93338.43
# messages          2109.66
# mb_used       98746498.93
# minutes_over         0.00
# messages_over        0.00
# mb_over        5911022.80
# total_profit    143360.43

# %%
# построим графики распределения для основных данных тарифа Ultra: минуты, смс и мб 

pd.plotting.scatter_matrix(ultra_only[['minutes', 'messages', \
                                       'mb_used', 'total_profit']], \
                           alpha = 0.3, figsize = (14,10))
plt.show()

# %% [markdown]
# Количество минут и сообщений имеют распределение Пуассона.
#
# Количество потраченных мб - распределение Гаусса.

# %%
# создадим сводную таблицу средних показателей для каждого тарифа

all_in_one.pivot_table(index='tariff', values = ['minutes', 'minutes_over', 'messages', \
                       'messages_over', 'mb_used', 'mb_over', \
                       'over_profit', 'total_profit'])
# Out:
#         mb_over  mb_used  messages  messages_over  minutes  minutes_over  \
# tariff
# smart   2769.36 16243.76     38.72           5.80   419.44         41.59
# ultra    753.79 19706.98     61.16           0.00   547.76          0.00
#
#         over_profit  total_profit
# tariff
# smart        744.31       1294.31
# ultra        120.94       2070.94

# %% [markdown]
# По данным видно, что пользователи тарифа Smart менее активны в классической связи - меньше разговаривают и пишут смс, чем пользователи Ultra. Но это они компенсируют почти такой же активностью в использовании интернета.
#
# Пользователи Smart'a в среднем переплачивают более чем в 2 раза, относительно абонентской платы. Но при этом выручка с данного тарифа все равно в среднем меньше общей выручки с тарифа Ultra.
#
# Пользователи тарифа Ultra не выходят за рамки пакета минут и смс. При этом довольно часто выходят за рамки мб вклченных в тариф. Но весьма незначительно.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Анализ использования тарифов выполнен отлично!</div> <br>
# <div style="border:solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
# На мой взгляд, можно дополнить рассмотрением  распределений по используемым услугам в разрезе тарифов, чтобы наглядно понять и увидеть описательные статистики</div> <br>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Комментарий студента
#
#
# Дополнил
#
#
#
# </div>
#
# ---

# %% [markdown]
# ## Шаг 4. Проверка гипотез

# %% [markdown]
# ### Гипотеза 1. Cредняя выручка пользователей тарифов «Ultra» и «Smart» различается

# %% [markdown]
# Нулевой гипотезой будет выражение "Средние наших выборок равны".
#
# Альтернативной гипотезой будет гипотеза задания -  "Средняя выручка пользователей тарифов «Ultra» и «Smart» различается"

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Гипотезы сформулированы верно✅</div> <br>

# %%
# уровень значимости - 0.05 
alpha = 0.05


results = st.ttest_ind(smart_only['total_profit'], ultra_only['total_profit'], equal_var = False)
print('P-value:', results.pvalue)

if (results.pvalue < alpha):
    print('Нулевая гипотеза отвергнута')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# P-value: 1.2414049931248708e-246
# Нулевая гипотеза отвергнута

# %% [markdown]
# Значит сформулированная альтернативная гипотеза не отвергается - средние наших выборок отличаются.

# %% [markdown]
# ### Гипотеза 2. Средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов

# %% [markdown]
# Нулевой гипотезой зададим выражение "Средняя выручка пользователей из Москвы равна выручке пользователей из других регионов".
#
# Альтернативной гипотезой будет гипотеза задания - "Средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов".

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Гипотезы сформулированы верно✅</div> <br>

# %%
# создадим две таблицы:
# moscow_only - только клиенты из Москвы
# other_only - только клиенты не относящиеся к Москве

moscow_only = all_in_one[all_in_one['city'] == 'Москва']
other_only = all_in_one[all_in_one['city'] != 'Москва']

display(moscow_only.sample(5))
display(other_only.sample(5))
# Out:
#       user_id     month  minutes  messages  mb_used  age churn_date    city  \
# 2787     1436     April   314.00     22.00 24963.00   75        NaT  Москва
# 3034     1476      June   491.00      4.00 14634.00   50        NaT  Москва
# 2434     1385      July   383.00    142.00 37589.00   26        NaT  Москва
# 2123     1339  December   617.00       NaN 20795.00   52        NaT  Москва
# 2791     1436      June   420.00     22.00 23440.00   75        NaT  Москва
#
#      first_name   last_name   reg_date tariff  messages_included  \
# 2787      Радим     Ерофеев 2018-04-04  ultra               1000
# 3034  Валентина    Семенова 2018-04-30  ultra               1000
# 2434      Алиса    Дубинина 2018-01-13  ultra               1000
# 2123   Григорий  Вишневский 2018-08-14  smart                 50
# 2791      Радим     Ерофеев 2018-04-04  ultra               1000
#
#       mb_per_month_included  minutes_included  rub_monthly_fee  rub_per_gb  \
# 2787                  30720              3000             1950         150
# 3034                  30720              3000             1950         150
# 2434                  30720              3000             1950         150
# 2123                  15360               500              550         200
# 2791                  30720              3000             1950         150
#
#       rub_per_message  rub_per_minute  minutes_over  messages_over  mb_over  \
# 2787                1               1             0              0        0
# 3034                1               1             0              0        0
# 2434                1               1             0              0     6869
# 2123                3               3           117              0     5435
# 2791                1               1             0              0        0
#
#       over_profit  total_profit
# 2787         0.00       1950.00
# 3034         0.00       1950.00
# 2434      1050.00       3000.00
# 2123      1551.00       2101.00
# 2791         0.00       1950.00
#       user_id      month  minutes  messages  mb_used  age churn_date  \
# 1262     1200   December   579.00     38.00 17988.00   36        NaT
# 175      1027     August   474.00     23.00 24898.00   62        NaT
# 153      1021  September  1115.00    113.00 18321.00   61        NaT
# 95       1012   November   206.00     25.00 22546.00   38        NaT
# 2773     1433    October   660.00    104.00 11613.00   71        NaT
#
#                  city first_name  last_name   reg_date tariff  \
# 1262  Санкт-Петербург     Тамара  Ларионова 2018-04-28  ultra
# 175      Петрозаводск  Владислав     Авдеев 2018-04-10  smart
# 153         Краснодар  Святослав    Тихонов 2018-04-26  ultra
# 95    Санкт-Петербург     Варлам   Соловьев 2018-03-28  smart
# 2773         Подольск    Клариса   Алёшкова 2018-01-05  smart
#
#       messages_included  mb_per_month_included  minutes_included  \
# 1262               1000                  30720              3000
# 175                  50                  15360               500
# 153                1000                  30720              3000
# 95                   50                  15360               500
# 2773                 50                  15360               500
#
#       rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute  \
# 1262             1950         150                1               1
# 175               550         200                3               3
# 153              1950         150                1               1
# 95                550         200                3               3
# 2773              550         200                3               3
#
#       minutes_over  messages_over  mb_over  over_profit  total_profit
# 1262             0              0        0         0.00       1950.00
# 175              0              0     9538      2000.00       2550.00
# 153              0              0        0         0.00       1950.00
# 95               0              0     7186      1600.00       2150.00
# 2773           160             54        0       642.00       1192.00

# %%
# проверим соотношения пользователей разных тарифов в кождой из выборок

display('Соотношение клиентов разных тарифов в Москве', moscow_only.pivot_table(index = 'tariff', values = 'total_profit', aggfunc = 'count'))
display('Соотношение клиентов разных тарифов в других регионах', other_only.pivot_table(index = 'tariff', values = 'total_profit', aggfunc = 'count'))
# Out:
# 'Соотношение клиентов разных тарифов в Москве'
#         total_profit
# tariff
# smart            386
# ultra            225
# 'Соотношение клиентов разных тарифов в других регионах'
#         total_profit
# tariff
# smart           1844
# ultra            761

# %% [markdown]
# Судя по данным - распределение клиентов по тарифам не зависит критично от региона. В Москве, что не может быть неожиданностью, чуть больше людей предпочитают дорогой тариф.

# %%
# уровень значимости - 0.05 
alpha = 0.05

results = st.ttest_ind(moscow_only['total_profit'], other_only['total_profit'], equal_var = False)
print('P-value:', results.pvalue)

if (results.pvalue < alpha):
    print('Нулевая гипотеза отвергнута')
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# P-value: 0.5086199993481282
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Полученное p-value =  0.43, а значит есть вероятность того, что отличие средних значений выборок случайно и нельзя отвергнуть нулевую гипотезу, которая говорит о равенстве средних значений выручки в Москве и регионах.
#
# Альтернативная гипотеза отвергнута.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Проверки выполнены корректно, результаты интрепретированы верно</div> <br>

# %% [markdown]
# ## Шаг 5. Общий вывод

# %% [markdown]
# Мы получили много данных израхных таблиц. Все они были не идеальны, но критичных моментов было мало - только пропуски и несоответсвие типов данных.
#
# Из имеющихся датафреймов были получены следующие данные для каждого пользователя:
# - количество потраченных минут по месяцам
# - количество отправлленых собщений по месяцам
# - количество потраченных мб по месяцам
#
# По каждом тарифному плану были посчитаны:
# - средние данные по количеству потраченных минут, сообщений и мб мобильного интернета
# - средние данные по количеству минут, сообщений и мб мобильного интернета сверх тарифа
# - стандартные отклонения по количеству потраченных минут, сообщений и мб мобильного интернета
# - дисперсия по количеству потраченных минут, сообщений и мб мобильного интернета
#
# Выводы по тарифам:
# - пользователи тарифа Smart чуть менее активно использут звонки и смс, но компенсируют это весьма приличным использованием интернета - почти равным использованию интернета пользователями тарифа Ultra
# - пользователи тарифа Smart явно испытывают недостаток включенных в траифный план возмржностей: они регулярно выходят за пределы и доплачивают за услуги
# - потзователи тарифа Ultra напроттив - почти не выходят за лимиты. Особенно это касаетя минут и кличества смс, а превышение по по мобильному интернету очень небольшие.
# - при всем при этом пользователи тарифа Ultra все равно оказываются гораздо прибыльнее пользователей Smart
#
#
# Проверка гипотез выявила, что:
# - средняя выручка пользователей тарифов «Ultra» и «Smart» скорее различается
# - средняя выручка пользователей из Москвы скорее не отличается от выручки пользователей из других регионов
#
#
# Рекоммендации.
#
# Однозначо - тариф Ultra наиболее выгоден для Мегалайн. И на него стоит сделать ставку.

# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# ## Общий комментарий
# Спасибо за проделанную работу🤝
#
# Михаил, ты хорошо выполнил работу, достаточно продробно изучил использование тарифов клиентами.
#
# У нас есть 1 недочет:
# - некорректное объединение таблиц
#
# По общему выводу - здорово, что ты оставил подробный общий вывод, но из него так и не ясно какой их тарифов более прибыльный для компании и что рекомендовать коммерческому департаменту?!
#
# Исправляй и отправляй на проверку🛠
